# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# constants
k_b = 1.381e-23

# %%
colors = [
    'red',
    'green',
    'blue',
    'yellow',
    'magenta',
    'cyan',
    'maroon',
    'olive',
    'navy',
    'gray'
]

# %%
# standard error formala

# %%
import os
import pandas as pd


def plotter(beta):

    figsize = (8, 6)  # Width and height in inches

    # Create a figure object with the specified size
    fig = plt.figure(figsize=figsize)
    
    ax = fig.add_subplot()


    random_color=list(np.random.choice(range(255),size=3))

    # Define the directory path
    
    betaAsString = str(beta)
    
    # directory = 'task5_data/0.2/'
    directory = 'task5_data/' + betaAsString + '/'

    # Initialize an empty list to store DataFrames
    dataframes = []

    # Loop through all files in the directory
    for filename in os.listdir(directory):
        # Check if the file is a regular file
        if os.path.isfile(os.path.join(directory, filename)):
            # Open the file with Pandas
            df = pd.read_csv(os.path.join(directory, filename))  # Assuming the file is CSV, change the function if needed
            
            r_correlation = df['r_correlation'][0]

            G = np.mean(df['G'])
            
            # G_err = 

            # G = df['G']
            
            
            
            color=[x/255 for x in random_color]
            
            ax.plot(r_correlation, G, linestyle="", marker='o', color=color)
            
            # Append the DataFrame to the list
            dataframes.append(df)

    # Concatenate all DataFrames into one
    combined_df = pd.concat(dataframes, ignore_index=True)

    # Now combined_df contains all data from all files in the directory
    
    plt.plot(r_correlation, G, linestyle="", marker='o', label=betaAsString, color=color)
    
    ax.legend()

    ax.set_xlabel("Distance between particles $r$")
    ax.set_ylabel("Correlation function $G_{ij}$")
    
    plt.show()

    # ax.xlabel("Distance between particles $r$")
    # ax.ylabel("Correlation function $G_{ij}$")
    
    # print(f"beta = {item}")

    
    
    return

# %%
plotter(0.2)

# %%
directory= 'task5_data'

# Loop through all items in the directory
for item in os.listdir(directory):
    # Check if the item is a directory
    if os.path.isdir(os.path.join(directory, item)):
        plotter(item)
# Out:
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
